# %%
import re
import pickle
import requests
import pandas as pd

from datetime import datetime, timedelta
from tqdm import tqdm

# %%
with open('data/raw.pkl', 'rb') as f:
    df = pickle.load(f)

df.head()
# Out:
#                                                          title  \
# id
# 8N3sFRR9-OE                     How bad is the Cheapest Laptop
# -n8N62DeNDU         WHY is Everyone Buying This Power Supply??
# buLyy7x2dcQ  Apple fans, start typing your angry comments now…
# H5e3ALqgpaA              I said YES to everything… I regret it
# P32OKr74NPQ         Upgrading our FREE internet to 25 gigabit!
#
#                      published_at  \
# id
# 8N3sFRR9-OE  2023-07-12T17:23:57Z
# -n8N62DeNDU  2023-07-11T17:03:27Z
# buLyy7x2dcQ  2023-07-10T18:14:04Z
# H5e3ALqgpaA  2023-07-09T17:20:35Z
# P32OKr74NPQ  2023-07-08T17:00:29Z
#
#                                                    description  \
# id
# 8N3sFRR9-OE  Check out the UGREEN Nexode 100W Charger, 145W...
# -n8N62DeNDU  Checkout iFixit's toolkits at: https://www.iFi...
# buLyy7x2dcQ  Check out the UGREEN PowerRoam 1200W, 145W Pow...
# H5e3ALqgpaA  Visit https://www.squarespace.com/LTT and use ...
# P32OKr74NPQ  It’s no secret their chairs are great! Check o...
#
#                                                           tags  \
# id
# 8N3sFRR9-OE                      [Cheapest Laptop, AliExpress]
# -n8N62DeNDU  [Power Supply, PSU Tester, Thermaltake Smart 6...
# buLyy7x2dcQ  [apple, mac, mac studio, apple silicon, m2, m2...
# H5e3ALqgpaA  [saying yes, roundup, tech, assorted, cuktech,...
# P32OKr74NPQ                                               None
#
#                                                   thumbnail  duration  \
# id
# 8N3sFRR9-OE  https://i.ytimg.com/vi/8N3sFRR9-OE/default.jpg  PT23M49S
# -n8N62DeNDU  https://i.ytimg.com/vi/-n8N62DeNDU/default.jpg  PT14M39S
# buLyy7x2dcQ  https://i.ytimg.com/vi/buLyy7x2dcQ/default.jpg  PT18M25S
# H5e3ALqgpaA  https://i.ytimg.com/vi/H5e3ALqgpaA/default.jpg  PT26M11S
# P32OKr74NPQ  https://i.ytimg.com/vi/P32OKr74NPQ/default.jpg  PT32M19S
#
#             view_count like_count comment_count  \
# id
# 8N3sFRR9-OE     453842      25856          1891
# -n8N62DeNDU    1116918      51871          2983
# buLyy7x2dcQ    1728263      70674          4720
# H5e3ALqgpaA    1823313      76297          3044
# P32OKr74NPQ    1835615      68739          2771
#
#                                                  transcription
# id
# 8N3sFRR9-OE  [{'text': 'I've got something I want to show y...
# -n8N62DeNDU  [{'text': 'this is the most popular power supp...
# buLyy7x2dcQ  [{'text': 'I really did try this time guys I e...
# H5e3ALqgpaA  [{'text': 'my inbox is full of opportunities t...
# P32OKr74NPQ  [{'text': 'when we expanded our space to give ...

# %% [markdown]
# # Missing values
#
# First we will check for missing values

# %%
df.isna().sum(axis=0)
# Out:
# title             0
# published_at      0
# description       0
# tags             81
# thumbnail         0
# duration          0
# view_count        0
# like_count        0
# comment_count     0
# transcription     1
# dtype: int64

# %% [markdown]
# As we can see we have 9% of the videos without tags and only 1 video without a transcription. We will keep this in mind during the analysis, but no need to go back to to the collection phase.

# %% [markdown]
# # Variable types

# %%
df.dtypes
# Out:
# title            object
# published_at     object
# description      object
# tags             object
# thumbnail        object
# duration         object
# view_count       object
# like_count       object
# comment_count    object
# transcription    object
# dtype: object

# %% [markdown]
# We want:
#
# - `published_at` to be a `datetime`
# - `duration` to be an `timedelta`

# %%
def parse_duration(text):
    '''
    '''
    h_search = re.search('(\d+)H', text)
    m_search = re.search('(\d+)M', text)
    s_search = re.search('(\d+)S', text)

    h = int(h_search.group(1) if h_search else 0)
    m = int(m_search.group(1) if m_search else 0)
    s = int(s_search.group(1) if s_search else 0)

    return timedelta(hours=h, minutes=m, seconds=s)

# visually inspected to match
# df['parsed_duration'] = df.duration.apply(parse_duration)
# with pd.option_context('display.max_rows', None):
#    display(df[['duration', 'parsed_duration']])

df['published_at'] = pd.to_datetime(df.published_at)
df['duration'] = df.duration.apply(parse_duration)

df.head()

# %% [markdown]
# ## Parsing the transcription
#
# The transcriptions are in a list where every entry is a dictionary with the following fields: `text`, `start`, and `duration`.
#
# Since one of the analysis we want to is the relationship between the script and video performance, we need to extract the `text`. I also have the hypothesis that the beginning of the video has a higher weight (namely before the sponsored segment), so we will extract the script at 1, 2, 5, and 10 minutes. We will also extract the full script.
#
# \* We will also use some Natural Language Processing techniques to process the text later

# %%
def parse_transcription(lines):
    '''
        lines: [{}]
        Since this is a one time thing, we will not try to optimize this
    '''
    if not lines:
        return [None] * 5
        
    before_1min = ' '.join([line.get('text') for line in lines if line.get('start') < 60])
    before_2min = ' '.join([line.get('text') for line in lines if line.get('start') < 2 * 60])
    before_5min = ' '.join([line.get('text') for line in lines if line.get('start') < 5 * 60])
    before_10min = ' '.join([line.get('text') for line in lines if line.get('start') < 10 * 60])
    all = ' '.join([line.get('text') for line in lines])

    return before_1min, before_2min, before_5min, before_10min, all
        

transcription_cols = ['1min_text', '2min_text', '5min_text', '10min_text', 'full_text']
df[transcription_cols] = df.apply(lambda row: parse_transcription(row.transcription),
                                  axis=1,
                                  result_type='expand')

df[transcription_cols].head()
# Out:
#                                                      1min_text  \
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...
#
#                                                      2min_text  \
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...
#
#                                                      5min_text  \
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...
#
#                                                     10min_text  \
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...
#
#                                                      full_text
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...

# %% [markdown]
# ## Thumbnails
#
# We also want to download all the thumbnails, as we intend to use them to check for relationships with performance.

# %%
for (id, src) in tqdm(zip(df.index, df.thumbnail)):
    response = requests.get(src)
    
    if response.status_code != 200:
        print(f'Could not download {id=} ({src=})')
        continue
    
    with open(f'data/thumbnails/{id}.jpg', 'wb') as f:
        f.write(response.content)
# Out:
# 900it [04:19,  3.47it/s]

# %% [markdown]
# # Draft

# %%
ans = requests.get('https://i.ytimg.com/vi/8N3sFRR9-OE/default.jpg')

# %%
with open(f'data/thumbnails/{id}.jpg', 'wb') as f:
    f.write(ans.content)

# %%
df.columns
# Out:
# Index(['title', 'published_at', 'description', 'tags', 'thumbnail', 'duration',
#        'view_count', 'like_count', 'comment_count', 'transcription',
#        'before_1min', 'before_2min', 'before_5min', 'before_10min',
#        'full_transcription', 'text_1min', 'text_2min', 'text_5min',
#        'text_10min', 'text_full', '1min_text', '2min_text', '5min_text',
#        '10min_text', 'full_text'],
#       dtype='object')

# %%
a = df[:10].copy(deep=True)

a[['b1', 'b2', 'b5', 'b10', 'all']] = a.apply(lambda row: parse_transcription(row.transcription), axis=1, result_type='expand')

# %%
a
# Out:
#                                                          title  \
# id
# 8N3sFRR9-OE                     How bad is the Cheapest Laptop
# -n8N62DeNDU         WHY is Everyone Buying This Power Supply??
# buLyy7x2dcQ  Apple fans, start typing your angry comments now…
# H5e3ALqgpaA              I said YES to everything… I regret it
# P32OKr74NPQ         Upgrading our FREE internet to 25 gigabit!
# diUOdC2tYzM      I Want an iPhone because iOS 17 Looks AMAZING
# QwIlhuR_N2g       The Scariest Fan ever attached to a computer
# JVBnJtzEuI0                       You'll regret spamming me...
# FLG08-xJGyM     This WEIRD Japanese Laptop LOOKS 20 Years Old…
# yI7fV88T8A0                 Apple's new Mac Pro can't do THIS!
#
#                          published_at  \
# id
# 8N3sFRR9-OE 2023-07-12 17:23:57+00:00
# -n8N62DeNDU 2023-07-11 17:03:27+00:00
# buLyy7x2dcQ 2023-07-10 18:14:04+00:00
# H5e3ALqgpaA 2023-07-09 17:20:35+00:00
# P32OKr74NPQ 2023-07-08 17:00:29+00:00
# diUOdC2tYzM 2023-07-06 16:58:35+00:00
# QwIlhuR_N2g 2023-07-05 17:13:58+00:00
# JVBnJtzEuI0 2023-07-04 19:54:33+00:00
# FLG08-xJGyM 2023-07-03 17:12:42+00:00
# yI7fV88T8A0 2023-07-02 17:43:18+00:00
#
#                                                    description  \
# id
# 8N3sFRR9-OE  Check out the UGREEN Nexode 100W Charger, 145W...
# -n8N62DeNDU  Checkout iFixit's toolkits at: https://www.iFi...
# buLyy7x2dcQ  Check out the UGREEN PowerRoam 1200W, 145W Pow...
# H5e3ALqgpaA  Visit https://www.squarespace.com/LTT and use ...
# P32OKr74NPQ  It’s no secret their chairs are great! Check o...
# diUOdC2tYzM  Save time and automate your social media marke...
# QwIlhuR_N2g  Looking for electronic components and equipmen...
# JVBnJtzEuI0  Check out MotionGrey’s ergonomic workplace sol...
# FLG08-xJGyM  Add a little fun and personality to your print...
# yI7fV88T8A0  You’ll be amazed at what you can do with Gramm...
#
#                                                           tags  \
# id
# 8N3sFRR9-OE                      [Cheapest Laptop, AliExpress]
# -n8N62DeNDU  [Power Supply, PSU Tester, Thermaltake Smart 6...
# buLyy7x2dcQ  [apple, mac, mac studio, apple silicon, m2, m2...
# H5e3ALqgpaA  [saying yes, roundup, tech, assorted, cuktech,...
# P32OKr74NPQ                                               None
# diUOdC2tYzM  [iOS 17, Android, Apple, iPhone, iOS, iPad, Ap...
# QwIlhuR_N2g  [Massive Fan, Highest Airflow PC, VF-390, Vasy...
# JVBnJtzEuI0  [Viture, Augmented Reality, Extended Reality, ...
# FLG08-xJGyM  [panasonic, laptop, let's note, japan, japanes...
# yI7fV88T8A0  [gaming, gpu, apple, mac, server, xeon, mac ga...
#
#                                                   thumbnail        duration  \
# id
# 8N3sFRR9-OE  https://i.ytimg.com/vi/8N3sFRR9-OE/default.jpg 0 days 00:23:49
# -n8N62DeNDU  https://i.ytimg.com/vi/-n8N62DeNDU/default.jpg 0 days 00:14:39
# buLyy7x2dcQ  https://i.ytimg.com/vi/buLyy7x2dcQ/default.jpg 0 days 00:18:25
# H5e3ALqgpaA  https://i.ytimg.com/vi/H5e3ALqgpaA/default.jpg 0 days 00:26:11
# P32OKr74NPQ  https://i.ytimg.com/vi/P32OKr74NPQ/default.jpg 0 days 00:32:19
# diUOdC2tYzM  https://i.ytimg.com/vi/diUOdC2tYzM/default.jpg 0 days 00:13:02
# QwIlhuR_N2g  https://i.ytimg.com/vi/QwIlhuR_N2g/default.jpg 0 days 00:19:39
# JVBnJtzEuI0  https://i.ytimg.com/vi/JVBnJtzEuI0/default.jpg 0 days 00:18:19
# FLG08-xJGyM  https://i.ytimg.com/vi/FLG08-xJGyM/default.jpg 0 days 00:09:44
# yI7fV88T8A0  https://i.ytimg.com/vi/yI7fV88T8A0/default.jpg 0 days 00:20:22
#
#             view_count like_count comment_count  \
# id
# 8N3sFRR9-OE     453842      25856          1891
# -n8N62DeNDU    1116918      51871          2983
# buLyy7x2dcQ    1728263      70674          4720
# H5e3ALqgpaA    1823313      76297          3044
# P32OKr74NPQ    1835615      68739          2771
# diUOdC2tYzM    1822896      75882          5049
# QwIlhuR_N2g    1823271      89575          7295
# JVBnJtzEuI0    2047050      72683          3678
# FLG08-xJGyM    1715804      65492          3442
# yI7fV88T8A0    1288371      47942          1574
#
#                                                  transcription  \
# id
# 8N3sFRR9-OE  [{'text': 'I've got something I want to show y...
# -n8N62DeNDU  [{'text': 'this is the most popular power supp...
# buLyy7x2dcQ  [{'text': 'I really did try this time guys I e...
# H5e3ALqgpaA  [{'text': 'my inbox is full of opportunities t...
# P32OKr74NPQ  [{'text': 'when we expanded our space to give ...
# diUOdC2tYzM  [{'text': 'just kidding it's me Yvonne I need ...
# QwIlhuR_N2g  [{'text': 'this is the vf390 a 390 millimeter ...
# JVBnJtzEuI0  [{'text': 'we get loads of emails from everyon...
# FLG08-xJGyM  [{'text': 'this laptop came out in 2022 and it...
# yI7fV88T8A0  [{'text': 'I have three apples that do not sup...
#
#                                                             b1  \
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...
# diUOdC2tYzM  just kidding it's me Yvonne I need help with o...
# QwIlhuR_N2g  this is the vf390 a 390 millimeter fan that is...
# JVBnJtzEuI0  we get loads of emails from everyone from esta...
# FLG08-xJGyM  this laptop came out in 2022 and it's packed f...
# yI7fV88T8A0  I have three apples that do not support pcie g...
#
#                                                             b2  \
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...
# diUOdC2tYzM  just kidding it's me Yvonne I need help with o...
# QwIlhuR_N2g  this is the vf390 a 390 millimeter fan that is...
# JVBnJtzEuI0  we get loads of emails from everyone from esta...
# FLG08-xJGyM  this laptop came out in 2022 and it's packed f...
# yI7fV88T8A0  I have three apples that do not support pcie g...
#
#                                                             b5  \
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...
# diUOdC2tYzM  just kidding it's me Yvonne I need help with o...
# QwIlhuR_N2g  this is the vf390 a 390 millimeter fan that is...
# JVBnJtzEuI0  we get loads of emails from everyone from esta...
# FLG08-xJGyM  this laptop came out in 2022 and it's packed f...
# yI7fV88T8A0  I have three apples that do not support pcie g...
#
#                                                            b10  \
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...
# diUOdC2tYzM  just kidding it's me Yvonne I need help with o...
# QwIlhuR_N2g  this is the vf390 a 390 millimeter fan that is...
# JVBnJtzEuI0  we get loads of emails from everyone from esta...
# FLG08-xJGyM  this laptop came out in 2022 and it's packed f...
# yI7fV88T8A0  I have three apples that do not support pcie g...
#
#                                                            all
# id
# 8N3sFRR9-OE  I've got something I want to show you meet my ...
# -n8N62DeNDU  this is the most popular power supply on the m...
# buLyy7x2dcQ  I really did try this time guys I even went as...
# H5e3ALqgpaA  my inbox is full of opportunities to review ev...
# P32OKr74NPQ  when we expanded our space to give the Creator...
# diUOdC2tYzM  just kidding it's me Yvonne I need help with o...
# QwIlhuR_N2g  this is the vf390 a 390 millimeter fan that is...
# JVBnJtzEuI0  we get loads of emails from everyone from esta...
# FLG08-xJGyM  this laptop came out in 2022 and it's packed f...
# yI7fV88T8A0  I have three apples that do not support pcie g...

# %%
type(df.iloc[0].transcription[0].get('start'))
# Out:
# float

# %%
pd.DataFrame(df.iloc[0].transcription)
# Out:
#                                         text     start  duration
# 0      I've got something I want to show you     0.000     5.299
# 1                   meet my big pink 10 inch     1.620     7.920
# 2     Netbook from AliExpress why you ask if     5.299     7.001
# 3    you sort all the new Windows laptops in     9.540     5.099
# 4         existence from low to high the top    12.300     6.180
# ..                                       ...       ...       ...
# 574         maybe check out that dual screen  1419.539     4.201
# 575    AliExpress laptop that we checked out  1421.640     4.080
# 576    recently where our community actually  1423.740     3.299
# 577      figured out a bunch of stuff on the  1425.720     5.000
# 578         Forum to dramatically improve it  1427.039     3.681
#
# [579 rows x 3 columns]

# %%
import re

re.findall('PT(\d+)M(\d+)S', 'PT9M1S')
# Out:
# [('9', '1')]

# %%
pattern = re.compile(r'(\d+)M')

a = re.search(r'(\d+)M', 'PT9M')

# %%
a.group(1)
# Out:
# '9'

# %%
df.published_at
# Out:
# 0      2023-07-12T17:23:57Z
# 1      2023-07-11T17:03:27Z
# 2      2023-07-10T18:14:04Z
# 3      2023-07-09T17:20:35Z
# 4      2023-07-08T17:00:29Z
#                ...
# 895    2020-08-26T07:00:21Z
# 896    2020-08-25T18:27:13Z
# 897    2020-08-24T16:59:58Z
# 898    2020-08-23T17:11:42Z
# 899    2020-08-22T17:57:21Z
# Name: published_at, Length: 900, dtype: object

# %%
pd.to_datetime(df.published_at)
# Out:
# 0     2023-07-12 17:23:57+00:00
# 1     2023-07-11 17:03:27+00:00
# 2     2023-07-10 18:14:04+00:00
# 3     2023-07-09 17:20:35+00:00
# 4     2023-07-08 17:00:29+00:00
#                  ...
# 895   2020-08-26 07:00:21+00:00
# 896   2020-08-25 18:27:13+00:00
# 897   2020-08-24 16:59:58+00:00
# 898   2020-08-23 17:11:42+00:00
# 899   2020-08-22 17:57:21+00:00
# Name: published_at, Length: 900, dtype: datetime64[ns, UTC]

# %%
df[df.drop('tags', axis=1).isna().any(axis=1)]
# Out:
#               id                                     title  \
# 708  dJwjqZZgcWk  LTT has a New Home... (April Fools 2021)
#
#              published_at                                        description  \
# 708  2021-04-01T13:50:12Z  Get a 15-day free trial for unlimited backup a...
#
#                                          tags  \
# 708  ['april fools', 'onlyfans', 'only fans']
#
#                                           thumbnail duration  view_count  \
# 708  https://i.ytimg.com/vi/dJwjqZZgcWk/default.jpg  PT4M36S     1697153
#
#      like_count  comment_count transcription
# 708      191214          27458           NaN

# %%
df[df.published_at.isna()]
# Out:
# Empty DataFrame
# Columns: [id, title, published_at, description, tags, thumbnail, duration, view_count, like_count, comment_count, transcription]
# Index: []

# %%
df.tail()
# Out:
#              id                                              title  \
# 25  2fKIaalk4_w                  I should stop building computers.
# 26  QgrVVyIzecM  There’s NO WAY this works - Debunking bogus ne...
# 27  bY4MTjVEtjE              There goes all my phone sponsorships…
# 28  SqB0lUcqFbA    Hating Apple is Getting REALLY Hard - WWDC 2023
# 29  O8gCqSmtkrM  This Broke One Week out of Warranty... Can I F...
#
#          views     time_ago                                      transcription
# 25  1.6M views  1 month ago  [{'text': 'last year we put together an absolu...
# 26  2.5M views  1 month ago  [{'text': 'on the surface this is the most sen...
# 27  2.2M views  1 month ago  [{'text': 'after 10 days of construction our b...
# 28    3M views  1 month ago  [{'text': 'Apple just demolished the competiti...
# 29  1.3M views  1 month ago  [{'text': 'this is one sad man he was just one...

# %%
import re

# Since we can't use months and years in timedelta
# and we're only approximating the create_date
# this approach converts it to days with the lambda
time_patterns = {
    'hours': (r'(\d)\s+hours?', lambda x: x / 24),
    'days': (r'(\d)\s+days?', lambda x: x),
    'months': (r'(\d)\s+months?', lambda x: x * 30),
    'years': (r'(\d)\s+years?', lambda x: x * 365)
}

def parse_time(text, rel_date=datetime.today()):
    '''
    Given what YouTube shows, returns the approximate date of publication

    It seems that there isn't a mix of patterns, so we will loop and return the
    first match
    '''
    for _, (pattern, f) in time_patterns.items():
        match = re.search(pattern, text)

        if match:
            amount = f(int(match.group(1)))
            
            return rel_date - timedelta(days=amount)

# %%
df['create_date'] = [parse_time(t) for t in df.time_ago]

# %%
df
# Out:
#              id                                              title  \
# 0   buLyy7x2dcQ  Apple fans, start typing your angry comments now…
# 1   H5e3ALqgpaA              I said YES to everything… I regret it
# 2   P32OKr74NPQ         Upgrading our FREE internet to 25 gigabit!
# 3   diUOdC2tYzM      I Want an iPhone because iOS 17 Looks AMAZING
# 4   QwIlhuR_N2g       The Scariest Fan ever attached to a computer
# 5   JVBnJtzEuI0                       You'll regret spamming me...
# 6   FLG08-xJGyM     This WEIRD Japanese Laptop LOOKS 20 Years Old…
# 7   yI7fV88T8A0                 Apple's new Mac Pro can't do THIS!
# 8   ZGy2kkWOxig                                The Compensation PC
# 9   _CxkmtBqGn8  Our Studio was a HUGE waste of money - New Cha...
# 10  O0srjKOOR4g    I’m actually getting MAD now. – RTX 4060 Review
# 11  tiCc6eez7FA              This Beautiful PC has an UGLY Secret…
# 12  cPUbFteFL5Q  You’ve lived without these. Stop it. – Handy T...
# 13  YBTARvcFZ1A        I Bought 10 Weird Keyboards from AliExpress
# 14  P2hey3mNnN0  Who let them do this?? - The $800 Solid Copper...
# 15  xa5dFAPpUBA  I tried 6 Tech Toys, here are the best… and th...
# 16  wl2IugfRMDk        Only YOU can fix GPU pricing... Here's how!
# 17  6oiIMUrbilw  We made a huge mistake... but the solutions is...
# 18  VK6GYwPTcw4  I'm Clearly Out of Touch - Roku Plus Series TV...
# 19  7nXVJBGowmY  Checking on my Investment in Person - Framewor...
# 20  y4r-9HsGpe0                         The All WOOD Gaming Setup!
# 21  gqii2PIT4Pg  We weren't expecting THIS - Custom 'YTX' gamin...
# 22  MbSqSZevKo8   WATCH OUT Power Supply Makers! – LTT Labs Update
# 23  F6Gi2LcXhxM  Mac Gaming Sucks...but that's CHANGING! - Appl...
# 24  XSkRGMeqh2o      WHAT did I just BUY on Facebook Marketplace??
# 25  2fKIaalk4_w                  I should stop building computers.
# 26  QgrVVyIzecM  There’s NO WAY this works - Debunking bogus ne...
# 27  bY4MTjVEtjE              There goes all my phone sponsorships…
# 28  SqB0lUcqFbA    Hating Apple is Getting REALLY Hard - WWDC 2023
# 29  O8gCqSmtkrM  This Broke One Week out of Warranty... Can I F...
#
#          views     time_ago  \
# 0   1.2M views  7 hours ago
# 1   1.6M views    1 day ago
# 2   1.7M views   2 days ago
# 3   1.7M views   3 days ago
# 4   1.7M views   5 days ago
# 5     2M views   6 days ago
# 6   1.6M views   7 days ago
# 7   1.2M views   8 days ago
# 8   1.4M views   9 days ago
# 9   2.3M views  10 days ago
# 10  2.5M views  12 days ago
# 11  1.1M views  13 days ago
# 12  1.5M views  2 weeks ago
# 13  1.9M views  2 weeks ago
# 14  1.3M views  2 weeks ago
# 15  1.1M views  2 weeks ago
# 16  1.3M views  2 weeks ago
# 17  1.1M views  3 weeks ago
# 18  1.4M views  3 weeks ago
# 19  1.6M views  3 weeks ago
# 20  1.5M views  3 weeks ago
# 21  1.7M views  3 weeks ago
# 22  1.4M views  3 weeks ago
# 23  1.3M views  4 weeks ago
# 24  2.2M views  4 weeks ago
# 25  1.6M views  1 month ago
# 26  2.5M views  1 month ago
# 27  2.2M views  1 month ago
# 28    3M views  1 month ago
# 29  1.3M views  1 month ago
#
#                                         transcription  timededlta  \
# 0   [{'text': 'I really did try this time guys I e...           1
# 1   [{'text': 'my inbox is full of opportunities t...           1
# 2   [{'text': 'when we expanded our space to give ...           1
# 3   [{'text': "just kidding it's me Yvonne I need ...           1
# 4   [{'text': 'this is the vf390 a 390 millimeter ...           1
# 5   [{'text': 'we get loads of emails from everyon...           1
# 6   [{'text': "this laptop came out in 2022 and it...           1
# 7   [{'text': 'I have three apples that do not sup...           1
# 8   [{'text': 'wow look at the size of this comput...           1
# 9   [{'text': 'you guys are not going to believe w...           1
# 10  [{'text': 'wow Nvidia', 'start': 1.7, 'duratio...           1
# 11  [{'text': 'how could something be so beautiful...           1
# 12  [{'text': 'get a load of this guy trying to ma...           1
# 13  [{'text': "you've seen one keyboard you've see...           1
# 14  [{'text': "I'm about to water cool a computer ...           1
# 15  [{'text': 'it used to be that kids wanted to b...           1
# 16  [{'text': "you're tired of your wallet getting...           1
# 17  [{'text': 'when we did our last update on the'...           1
# 18  [{'text': "during roku's rise I was using Wind...           1
# 19  [{'text': 'product shortages have become an', ...           1
# 20  [{'text': 'your so has had enough of the giant...           1
# 21  [{'text': 'have you ever gotten a delivery you...           1
# 22  [{'text': 'I am going to blow up this power su...           1
# 23  [{'text': "this is a gaming PC and I'm not tal...           1
# 24  [{'text': "I gotta be honest with you guys I d...           1
# 25  [{'text': 'last year we put together an absolu...           1
# 26  [{'text': 'on the surface this is the most sen...           1
# 27  [{'text': 'after 10 days of construction our b...           1
# 28  [{'text': 'Apple just demolished the competiti...           1
# 29  [{'text': 'this is one sad man he was just one...           1
#
#                   create_date
# 0  2023-07-11 14:55:18.952608
# 1  2023-07-10 21:55:18.952608
# 2  2023-07-09 21:55:18.952608
# 3  2023-07-08 21:55:18.952608
# 4  2023-07-06 21:55:18.952608
# 5  2023-07-05 21:55:18.952608
# 6  2023-07-04 21:55:18.952608
# 7  2023-07-03 21:55:18.952608
# 8  2023-07-02 21:55:18.952608
# 9  2023-07-11 21:55:18.952608
# 10 2023-07-09 21:55:18.952608
# 11 2023-07-08 21:55:18.952608
# 12                        NaT
# 13                        NaT
# 14                        NaT
# 15                        NaT
# 16                        NaT
# 17                        NaT
# 18                        NaT
# 19                        NaT
# 20                        NaT
# 21                        NaT
# 22                        NaT
# 23                        NaT
# 24                        NaT
# 25 2023-06-11 21:55:18.952608
# 26 2023-06-11 21:55:18.952608
# 27 2023-06-11 21:55:18.952608
# 28 2023-06-11 21:55:18.952608
# 29 2023-06-11 21:55:18.952608

# %%
parse_time(df.iloc[0].time_ago)
# Out:
# 7:00:00
# datetime.datetime(2023, 7, 11, 14, 45, 24, 973490)

# %%
matches.group(1)
# Out:
# '7'

# %%
df.iloc[0].time_ago
# Out:
# '7 hours ago'

# %%
from datetime import datetime, timedelta

# %%
timedelta(df.iloc[0].time_ago)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 timedelta(df.iloc[0].time_ago)
#
# TypeError: unsupported type for timedelta days component: str

# %% [markdown]
# For the first step we will clear the `views`, transforming them into numbers.

# %%
def parse_views(text):
    '''
    There seems to be a couple of cases:
        - Contains dot
            - 8.8K -> Replace '.' with '' -> replace 'K' with '00'
            - 1.4M -> Replace '.' with '' -> replace 'M' with '00000'
        - Without dots
            - 394K -> Replace 'K' with '000'
            - 2M -> Replace 'M' with '000000'
            
    Then we remove the 'views', strip and parse as int
    '''
    if '.' in text:
        k_replace = '00'
        m_replace = '00000'
    else:
        k_replace = '000'
        m_replace = '000000'

    views = int(text\
                .replace('.', '')\
                .replace('K', k_replace)\
                .replace('M', m_replace)\
                .replace('views', '')\
                .strip())
    
    return views

df['clean_views'] = [parse_views(view_text) for view_text in df.views]

# %%
df.head()
# Out:
#             id                                              title       views  \
# 0  buLyy7x2dcQ  Apple fans, start typing your angry comments now…  1.2M views
# 1  H5e3ALqgpaA              I said YES to everything… I regret it  1.6M views
# 2  P32OKr74NPQ         Upgrading our FREE internet to 25 gigabit!  1.7M views
# 3  diUOdC2tYzM      I Want an iPhone because iOS 17 Looks AMAZING  1.7M views
# 4  QwIlhuR_N2g       The Scariest Fan ever attached to a computer  1.7M views
#
#                                        transcription  clean_views
# 0  [{'text': 'I really did try this time guys I e...      1200000
# 1  [{'text': 'my inbox is full of opportunities t...      1600000
# 2  [{'text': 'when we expanded our space to give ...      1700000
# 3  [{'text': "just kidding it's me Yvonne I need ...      1700000
# 4  [{'text': 'this is the vf390 a 390 millimeter ...      1700000

# %%
df
# Out:
#              id                                              title  \
# 0   buLyy7x2dcQ  Apple fans, start typing your angry comments now…
# 1   H5e3ALqgpaA              I said YES to everything… I regret it
# 2   P32OKr74NPQ         Upgrading our FREE internet to 25 gigabit!
# 3   diUOdC2tYzM      I Want an iPhone because iOS 17 Looks AMAZING
# 4   QwIlhuR_N2g       The Scariest Fan ever attached to a computer
# 5   JVBnJtzEuI0                       You'll regret spamming me...
# 6   FLG08-xJGyM     This WEIRD Japanese Laptop LOOKS 20 Years Old…
# 7   yI7fV88T8A0                 Apple's new Mac Pro can't do THIS!
# 8   ZGy2kkWOxig                                The Compensation PC
# 9   _CxkmtBqGn8  Our Studio was a HUGE waste of money - New Cha...
# 10  O0srjKOOR4g    I’m actually getting MAD now. – RTX 4060 Review
# 11  tiCc6eez7FA              This Beautiful PC has an UGLY Secret…
# 12  cPUbFteFL5Q  You’ve lived without these. Stop it. – Handy T...
# 13  YBTARvcFZ1A        I Bought 10 Weird Keyboards from AliExpress
# 14  P2hey3mNnN0  Who let them do this?? - The $800 Solid Copper...
# 15  xa5dFAPpUBA  I tried 6 Tech Toys, here are the best… and th...
# 16  wl2IugfRMDk        Only YOU can fix GPU pricing... Here's how!
# 17  6oiIMUrbilw  We made a huge mistake... but the solutions is...
# 18  VK6GYwPTcw4  I'm Clearly Out of Touch - Roku Plus Series TV...
# 19  7nXVJBGowmY  Checking on my Investment in Person - Framewor...
# 20  y4r-9HsGpe0                         The All WOOD Gaming Setup!
# 21  gqii2PIT4Pg  We weren't expecting THIS - Custom 'YTX' gamin...
# 22  MbSqSZevKo8   WATCH OUT Power Supply Makers! – LTT Labs Update
# 23  F6Gi2LcXhxM  Mac Gaming Sucks...but that's CHANGING! - Appl...
# 24  XSkRGMeqh2o      WHAT did I just BUY on Facebook Marketplace??
# 25  2fKIaalk4_w                  I should stop building computers.
# 26  QgrVVyIzecM  There’s NO WAY this works - Debunking bogus ne...
# 27  bY4MTjVEtjE              There goes all my phone sponsorships…
# 28  SqB0lUcqFbA    Hating Apple is Getting REALLY Hard - WWDC 2023
# 29  O8gCqSmtkrM  This Broke One Week out of Warranty... Can I F...
#
#          views                                      transcription
# 0   1.2M views  [{'text': 'I really did try this time guys I e...
# 1   1.6M views  [{'text': 'my inbox is full of opportunities t...
# 2   1.7M views  [{'text': 'when we expanded our space to give ...
# 3   1.7M views  [{'text': "just kidding it's me Yvonne I need ...
# 4   1.7M views  [{'text': 'this is the vf390 a 390 millimeter ...
# 5     2M views  [{'text': 'we get loads of emails from everyon...
# 6   1.6M views  [{'text': "this laptop came out in 2022 and it...
# 7   1.2M views  [{'text': 'I have three apples that do not sup...
# 8   1.4M views  [{'text': 'wow look at the size of this comput...
# 9   2.3M views  [{'text': 'you guys are not going to believe w...
# 10  2.5M views  [{'text': 'wow Nvidia', 'start': 1.7, 'duratio...
# 11  1.1M views  [{'text': 'how could something be so beautiful...
# 12  1.5M views  [{'text': 'get a load of this guy trying to ma...
# 13  1.9M views  [{'text': "you've seen one keyboard you've see...
# 14  1.3M views  [{'text': "I'm about to water cool a computer ...
# 15  1.1M views  [{'text': 'it used to be that kids wanted to b...
# 16  1.3M views  [{'text': "you're tired of your wallet getting...
# 17  1.1M views  [{'text': 'when we did our last update on the'...
# 18  1.4M views  [{'text': "during roku's rise I was using Wind...
# 19  1.6M views  [{'text': 'product shortages have become an', ...
# 20  1.5M views  [{'text': 'your so has had enough of the giant...
# 21  1.7M views  [{'text': 'have you ever gotten a delivery you...
# 22  1.4M views  [{'text': 'I am going to blow up this power su...
# 23  1.3M views  [{'text': "this is a gaming PC and I'm not tal...
# 24  2.2M views  [{'text': "I gotta be honest with you guys I d...
# 25  1.6M views  [{'text': 'last year we put together an absolu...
# 26  2.5M views  [{'text': 'on the surface this is the most sen...
# 27  2.2M views  [{'text': 'after 10 days of construction our b...
# 28    3M views  [{'text': 'Apple just demolished the competiti...
# 29  1.3M views  [{'text': 'this is one sad man he was just one...
